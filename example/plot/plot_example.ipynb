# %%
import altair as alt
alt.renderers.enable("png")
# Out:
# RendererRegistry.enable('png')

# %%
from cogclassifier.plot import plot_cog_count_barchart

cog_count_file = "./cog_count.tsv"
barchart = plot_cog_count_barchart(cog_count_file)
barchart
# Out:
# alt.Chart(...)

# %%
from cogclassifier.plot import plot_cog_count_barchart

cog_count_file = "./cog_count.tsv"
barchart = plot_cog_count_barchart(cog_count_file, percent_style=True, sort=True)
barchart
# Out:
# alt.Chart(...)

# %%
from cogclassifier.plot import plot_cog_count_barchart

cog_count_file = "./cog_count.tsv"
barchart = plot_cog_count_barchart(
    cog_count_file, fig_width=340, bar_width=8, y_limit=400
)
barchart
# Out:
# alt.Chart(...)

# %%
from cogclassifier.plot import plot_cog_count_barchart

cog_count_file = "./cog_count_add_no_classify.tsv"
barchart = plot_cog_count_barchart(cog_count_file)
barchart
# Out:
# alt.Chart(...)

# %%
from cogclassifier.plot import plot_cog_count_barchart

cog_count_file = "./cog_count_change_color.tsv"
barchart = plot_cog_count_barchart(cog_count_file)
barchart
# Out:
# alt.Chart(...)

# %%
from cogclassifier.plot import plot_cog_count_piechart

cog_count_file = "./cog_count.tsv"
piechart = plot_cog_count_piechart(cog_count_file, show_letter=True, sort=False)
piechart
# Out:
# alt.LayerChart(...)

# %%
from cogclassifier.plot import plot_cog_count_piechart

cog_count_file = "./cog_count.tsv"
piechart = plot_cog_count_piechart(cog_count_file, show_letter=True, sort=True)
piechart
# Out:
# alt.LayerChart(...)

# %%
from cogclassifier.plot import plot_cog_count_piechart

cog_count_file = "./cog_count_add_no_classify.tsv"
piechart = plot_cog_count_piechart(cog_count_file, show_letter=True)
piechart
# Out:
# alt.LayerChart(...)
